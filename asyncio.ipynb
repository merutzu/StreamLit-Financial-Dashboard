# %%
import config
import configuration
import json
import requests
import datetime, time
import aiohttp, asyncpg, asyncio
api_key = 'sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq'

# %%
async def write_to_db(connection, params):
    await connection.copy_records_to_table('stock_price', records=params)


async def get_price(pool, stock_id, url):
    try: 
        async with pool.acquire() as connection:
            async with aiohttp.ClientSession() as session:
                async with session.get(url=url) as response:
                    resp = await response.read()
                    response = json.loads(resp)
                    params = [(stock_id, datetime.datetime.fromtimestamp(bar['t'] / 1000.0), round(bar['o'], 2), round(bar['h'], 2), round(bar['l'], 2), round(bar['c'], 2), bar['v']) for bar in response['results']]
                    await write_to_db(connection, params)

    except Exception as e:
        print("Unable to get url {} due to {}.".format(url, e.__class__))


async def get_prices(pool, symbol_urls):
    try:
        # schedule aiohttp requests to run concurrently for all symbols
        ret = await asyncio.gather(*[get_price(pool, stock_id, symbol_urls[stock_id]) for stock_id in symbol_urls])
        print("Finalized all. Returned  list of {} outputs.".format(len(ret)))
    except Exception as e:
        print(e)


async def get_stocks():
    # create database connection pool
    pool = await asyncpg.create_pool(user=config.DB_USER, password=config.DB_PASS, database=config.DB_NAME, host=config.DB_HOST, port=config.DB_PORT, command_timeout=60)
    
    # get a connection
    async with pool.acquire() as connection:
        stocks = await connection.fetch("SELECT * FROM stock WHERE id IN (SELECT holding_id FROM etf_holding)")

        symbol_urls = {} 
        for stock in stocks:
            symbol_urls[stock['id']] = f"https://api.polygon.io/v2/aggs/ticker/{stock['symbol']}/range/5/minute/2022-07-01/2022-10-05?apiKey={api_key}&limit=50000"

    await get_prices(pool, symbol_urls)


start = time.time()

# asyncio.run(get_stocks())
await get_stocks()


end = time.time()

print("Took {} seconds.".format(end - start))
# Out:
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ZM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TARO/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CRS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SLGC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NTLA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VCYT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BLDE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RDWR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TEVA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PSNL/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'asyncpg.exceptions.UniqueViolationError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GILT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'asyncpg.exceptions.UniqueViolationError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/INTU/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'asyncpg.exceptions.UniqueViolationError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BFLY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TWOU/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MTLS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/EMN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GH/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TSP/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/IOVA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/AUDC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/IS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SMWB/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TSEM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ACCD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/KTOS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/WIX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NRIX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SPNS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MRNA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/REGN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PACB/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TWTR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CRWD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CGEN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ISRG/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/KIND/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BILL/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TWST/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TER/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CRSP/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NVMI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PATH/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BYDDY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/IRDM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PTC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/Z/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/XMTR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SSYS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/HLAN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TUFN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RADA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PRLB/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TDY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CLBT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CGNT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SGFY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NVDA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DSM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MMM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DDD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ONEM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/WKME/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/LECO/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PTNR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MNDY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TDOC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/KMTUY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GOOG/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ANSS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/KODK/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ALTR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/COIN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CHKP/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/JD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RPTX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ZY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FARO/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/AME/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NIO/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MELI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/AVAV/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ITRN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ICE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NET/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TSLA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SAND/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SQ/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ACAH/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ML/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MGA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VOE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GENI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VEEV/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ADYEY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PYR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SILC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ESLT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VUZI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ATI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CYBR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RSKD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/AJRD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GBTC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MASS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/DNA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SNPS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ADSK/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/HXL/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SNTI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VERV/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TRMB/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NVTA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/XRX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RXRX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/EVK/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TWLO/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MGIC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ALLT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FVRR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/HOOD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FROG/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MTRX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ARNC/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GLBE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PLTK/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/RBLX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/GM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MKFG/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CRNT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ADPT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TOST/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ROKU/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/MSFT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NICE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NNOX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NNDM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PERI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/QSI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FTCH/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VRTX/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FATH/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SHOP/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CERS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BEAM/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/EXAS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/U/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/NIU/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/PFE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SURF/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/LMT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/BLI/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/FATE/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TXG/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ACHR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CMPS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SDGR/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/SPOT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/IONS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/INMD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/KALU/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/VLD/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CAT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CDXS/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/HPQ/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/TBLA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CDNA/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/INCY/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/XPEV/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/ALGN/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Unable to get url https://api.polygon.io/v2/aggs/ticker/CAMT/range/5/minute/2022-07-01/2022-10-05?apiKey=sbHpjGK6kVi3pbbRIayD4jN8UIQtGRKq&limit=50000 due to <class 'KeyError'>.
# Finalized all. Returned  list of 179 outputs.
# Took 6.117429733276367 seconds.

# %%
#### ADDING GME STATS 


async def write_to_db(connection, params):
    await connection.copy_records_to_table('stock_price', records=params)


async def get_price(pool, stock_id, url):
    try: 
        async with pool.acquire() as connection:
            async with aiohttp.ClientSession() as session:
                async with session.get(url=url) as response:
                    resp = await response.read()
                    response = json.loads(resp)
                    params = [(stock_id, datetime.datetime.fromtimestamp(bar['t'] / 1000.0), round(bar['o'], 2), round(bar['h'], 2), round(bar['l'], 2), round(bar['c'], 2), bar['v']) for bar in response['results']]
                    await write_to_db(connection, params)

    except Exception as e:
        print("Unable to get url {} due to {}.".format(url, e.__class__))


async def get_prices(pool, symbol_urls):
    try:
        # schedule aiohttp requests to run concurrently for all symbols
        ret = await asyncio.gather(*[get_price(pool, stock_id, symbol_urls[stock_id]) for stock_id in symbol_urls])
        print("Finalized all. Returned  list of {} outputs.".format(len(ret)))
    except Exception as e:
        print(e)


async def get_stocks():
    # create database connection pool
    pool = await asyncpg.create_pool(user=config.DB_USER, password=config.DB_PASS, database=config.DB_NAME, host=config.DB_HOST, port=config.DB_PORT, command_timeout=60)
    
    # get a connection
    async with pool.acquire() as connection:
        stocks = await connection.fetch("SELECT * FROM stock WHERE symbol = 'GME'")

        symbol_urls = {} 
        for stock in stocks:
            symbol_urls[stock['id']] = f"https://api.polygon.io/v2/aggs/ticker/GME/range/5/minute/2022-07-01/2022-10-05?apiKey={api_key}&limit=50000"

    await get_prices(pool, symbol_urls)


start = time.time()

# asyncio.run(get_stocks())
await get_stocks()


end = time.time()

print("Took {} seconds.".format(end - start))
# Out:
# Finalized all. Returned  list of 1 outputs.
# Took 1.251145839691162 seconds.
