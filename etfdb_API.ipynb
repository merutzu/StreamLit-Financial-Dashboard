# %%
import alpaca_trade_api as tradeapi
import psycopg2
import psycopg2.extras
import config
import configuration
import csv

# %%
connection = psycopg2.connect(host=config.DB_HOST, database=config.DB_NAME, user=config.DB_USER, password=config.DB_PASS, port=config.DB_PORT)

cursor = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

api = tradeapi.REST(configuration.API_KEY, configuration.API_SECRET, base_url=configuration.API_URL)

assets = api.list_assets()

# %%
for asset in assets:
    print(f"Inserting stock {asset.name} {asset.symbol}")
    cursor.execute("""
        INSERT INTO stock (name, symbol, exchange, is_etf)
        VALUES (%s, %s, %s, false)     
    """, (asset.name, asset.symbol, asset.exchange))
# Out:
# Inserting stock BrightRock Gold Corporation Common Stock NEW BRGC
# Inserting stock FENIXORO GOLD CORP Common Shares FDVXF
# Inserting stock DIABLO RES LTD ORDINARY FULLY PAID (Australia) DBORF
# Inserting stock Acreage Holdings, Inc. Class D Sub Vtg Ord Shs (Canada) ACRDF
# Inserting stock TFN Football Network (The) Common Stock TFBN
# Inserting stock CENTRAL PUERTO SA ORD 1 VOTO ESCRIT (Argentina) CEPPF
# Inserting stock Creso Pharma Ltd Ordinary Shares (Australia) COPHF
# Inserting stock Hyperblock Inc HYBOF
# Inserting stock Knorr-Bremse AG American Depositary Receipts - Unsponsored (Germany Federal Republic) KNRRY
# Inserting stock Bango plc Cambridge Ordinary Shares (United Kingdom) BGOPF
# Inserting stock FutureWorld Corp. Common Stock FWDG
# Inserting stock Bunge Limited 4.875% Perpetual Pref Shs Conv (Bermuda) BGEPF
# Inserting stock Hutchinson Port Holdings Trust Units (Singapore) HCTPF
# ...

# %%
connection.commit()
